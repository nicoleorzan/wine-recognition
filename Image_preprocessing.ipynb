# %%
import cv2

try:
    from PIL import Image
except ImportError:
    import Image
    
import pytesseract

import os
import tempfile
import numpy as np
import imutils

# %%
def image_smoothening(img, BINARY_THREHOLD=255):
    
    # binary image thresholding
    ret1, th1 = cv2.threshold(img, BINARY_THREHOLD, 255, cv2.THRESH_BINARY)
    
    # OTSU's binarization, useful to choose arbitrarily the threshold value to binarize the image.
    # thresholding value is determined from the peaks of the image histogram
    ret2, th2 = cv2.threshold(th1, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    
    # Gaussian blur: blurring an image by a Gaussian function to reduce noise (and detail)
    blur = cv2.GaussianBlur(th2, (1, 1), 0)
    
    ret3, th3 = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    
    return th3



def remove_noise_and_smooth(file_name):
    
    img = cv2.imread(file_name, 0)
    
    # Trasforming a grayscale image to a binary image, computing the threshold individually for each pixel.
    # the thres val is a mean of the blockSize*blockSize (9x9) neighborhood of the pixel minus C=41.
    filtered = cv2.adaptiveThreshold(img.astype(np.uint8), 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 9, 41)
    
    # morphological transformations of opening (erosion followed by dilation)
    # and closing (erosion followed by dilation)
    kernel = np.ones((1, 1), np.uint8)
    opening = cv2.morphologyEx(filtered, cv2.MORPH_OPEN, kernel)
    closing = cv2.morphologyEx(opening, cv2.MORPH_CLOSE, kernel)
    
    # applying smothening
    img = image_smoothening(img)
    # Applying morphological operators
    or_image = cv2.bitwise_or(img, closing)
    
    return or_image

# %% [markdown]
# ### Image opening
#
# <img src="Images/opening.png" alt="drawing" style="width:200px;"/>
#
# ### Image closing
#
# <img src="Images/closing.png" alt="drawing" style="width:200px;"/>

# %%
filename = '5.jpg'
img = remove_noise_and_smooth(filename)
img_old = cv2.imread(filename,0)

cv2.namedWindow("image", cv2.WINDOW_NORMAL)
cv2.resizeWindow('image', 600,600)
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # OCR on preprocessed Images

# %%
pytesseract.image_to_string(img_old)
# Out:
# 'A Love of Wine and Fa mily\n\n{ rf 1 1 \\ }\nT T 1\nASTING NOTES / Our Pinot Gris is a dry, crisp white wine offering\n\napple, floral, honey-tinged flavors with a citrus kick. Enjoy this wine\nalor\n\n \n\nje seafood, pork, chicken, fish, creamy sauce dishes, light\nsalads or sandwiches and strong cheeses.\n\n| 181\nchairs while docked on\n\n8\naco GOVERNMENT WARNING: (1)\n‘ ACCORDING TO THE SURGEON\nGENERAL, WOMEN SHOULD NOT\n. DRINK ALCOHOLIC BEVERAGES\nven Qucensbury, New York DURING. PREGNANCY BECAUSE\n\n2016 | NEW YORK\nPINOT GRIS\n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\nTaking a break with 7 | 2al37957!ll,\nPinot Gris in Adirondack\n\nOF THE RISK OF BIRTH DEFECTS.\nwww.AdirondackWinery.com 2) CONSUMPTION OF ALCOHOLIC\nrere Ween BEVERAGES IMPAIRS YOUR\n\nABILITY TO DRIVE A CAR OR\nOPERATE MACHINERY, AND MAY\n385 Canada Street CAUSE HEALTH PROBLEMS.\n\nLake George, New York 12845 CONTAINS SULFITES'

# %%
pytesseract.image_to_string(img)
# Out:
# 'A Love of Wine and Family has brought us\nback to our roots in the beautiful Adirondacks to\nshare our award-winning, locally-handcrafted wines\nwith friends new and old. From our family to yours,\nthank you for heing a part of our story and for letting\nus be a part of yours!\n\nSEMEDRY\nTASTING NOTES / Our Pinot Gris is a dry, crisp white wine offering\napple, floral, honcy-tinged flavors with a citrus kick. Enjoy this wine\nalongside seafood, pork, chicken, fish, creamy sauce dishes, light\nsalads or sandwiches and strong cheeses.\n\n \n\nSEMI-SWEET\n\n2016 | NEW YORK\n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\nPINOT GRIS\nLYRONT IMAGE «\nTaking a break with 7 Me gi2allszg5 zl,\nPinot G in Adirondack\nchairs while docked on\nLake George, GOVERNMENT WARNING: (1)\n" ACCORDING TO THE SURGEON\npropve:y «rovtecy ow GENERAL, WOMEN SHOULD NOT\n\nDRINK ALCOHOLIC BEVERAGES\nDURING PREGNANCY BECAUSE\nOF THE RISK OF BIRTH DEFECTS.\n(2) CONSUMPTION OF ALCOHOLIC\nBEVERAGES IMPAIRS YOUR\nABILITY TO DRIVE A CAR OR\n\nADIRONDACK WINERY, tic\nQueensbury, New York\n\nwww. Adirondack Winery.com\n(518) 668-WINE\n\n¥ SIT OUR TASTING ROOST A\n285 Canada Street\nLake George, New York 12845\n\nOPERATE MACHINERY, AND MAY\nCAUSE HEALTH PROBLEMS.\n\nCONTAINS SULFITES'

# %% [markdown]
# ### Applying OCR on folder

# %%
directory = '../back_labels_wine/'

jsons = {}

i = 1
for filename in os.listdir(directory):
    if (i < 600):
        fn = directory + filename
        print(i, r'{}'.format(filename))
        i+=1
        #img = cv2.imread(r'{}'.format(fn))
        img = remove_noise_and_smooth('{}'.format(fn))
        jsons[i] = pytesseract.image_to_string(img)
# Out:
# 1 465.jpg
# 2 391.jpg
# 3 535.jpg
# 4 544.jpg
# 5 509.png
# 6 388.jpg
# 7 307.jpg
# 8 372.jpg
# 9 232.jpg
# 10 241.jpg
# 11 483.png
# 12 123.jpg
# 13 480.jpg
# 14 561.jpg
# 15 116.jpg
# 16 577.jpg
# 17 597.jpg
# 18 585.jpg
# 19 408.png
# 20 479.jpg
# 21 220.jpg
# 22 342.jpg
# 23 184.jpg
# 24 458.JPG
# 25 482.jpg
# 26 113.png
# 27 305.jpg
# 28 401.jpg
# 29 331.png
# 30 221.jpg
# 31 224.jpg
# 32 311.jpg
# 33 413.jpg
# 34 261.jpg
# 35 320.jpg
# 36 240.jpg
# 37 511.jpg
# 38 234.jpg
# 39 586.jpg
# 40 397.png
# 41 476.jpg
# 42 200.png
# 43 290.jpg
# 44 242.jpg
# 45 495.jpg
# 46 527.png
# 47 151.jpg
# 48 383.jpg
# 49 464.jpg
# 50 545.jpg
# 51 395.jpg
# 52 357.jpg
# 53 313.jpg
# 54 197.jpg
# 55 201.png
# 56 238.jpg
# 57 110.jpg
# 58 179.jpg
# 59 276.png
# 60 477.jpg
# 61 314.png
# 62 327.jpg
# 63 121.jpg
# 64 249.jpg
# 65 152.jpg
# 66 591.jpg
# 375 332.jpg
# 376 531.jpg
# 377 287.jpg
# 378 360.jpg
# 379 404.jpg
# 380 154.jpg
# 381 266.jpg
# 382 442.jpg
# 383 207.jpg
# 384 540.jpg
# 385 505.png
# 386 301.jpg
# 387 583.png
# 388 452.jpg
# 389 371.jpg
# 390 438.jpg
# 391 317.jpg
# 392 127.jpg
# 393 333.jpg
# 394 498.jpg
# 395 552.jpg
# 396 549.jpg
# 397 446.jpg
# 398 459.jpg
# 399 356.jpg
# 400 222.jpg
# 401 402.png
# 402 361.jpg
# 403 216.jpg
# 404 170.jpg
# 405 269.jpg
# 406 136.jpg
# 407 436.JPG
# 408 122.jpg
# 409 481.jpg
# 410 282.jpg
# 411 389.jpg
# 412 309.jpg
# 413 453.jpg
# 414 417.jpg
# 415 525.jpg
# 416 422.jpg
# 417 264.jpg
# 418 492.jpg
# 419 432.jpg
# 420 275.jpg
# 421 230.jpg
# 422 255.jpg
# 423 111.jpg
# 424 536.jpg
# 425 497.jpg
# 426 484.jpg
# 427 141.jpg
# 428 202.png
# 429 367.jpg
# 430 101.jpg
# 431 587.jpg
# 432 162.jpg
# 433 175.jpg
# 434 144.jpg
# 435 213.png
# 436 303.jpg
# 437 425.jpg
# 438 208.jpg
# 439 191.jpg
# 440 494.jpg
# 441 414.jpg
# 442 385.jpg
# 443 267.png
# 444 599.jpg
# 445 194.jpg
# 446 231.jpg
# 447 406.jpg
# 448 296.jpg
# 449 193.jpg
# 450 204.jpg
# 451 543.jpg
# 452 168.jpg
# 453 10.png
# 454 496.png
# 455 574.jpg
# 456 463.jpg
# 457 188.jpg
# 458 593.jpg
# 459 473.jpg
# 460 149.jpg
# 461 548.jpg
# 462 328.jpg
# 463 323.jpg
# 464 273.jpg
# 465 294.jpg
# 466 348.jpg
# 467 325.jpg
# 468 386.jpg
# 469 550.jpg
# 470 576.jpg
# 471 429.jpg
# 472 215.jpg
# 473 306.jpg
# 474 557.jpg
# 475 380.jpg
# 476 291.jpg
# 477 514.jpg
# 478 507.jpg
# 479 341.jpg
# 480 365.jpg
# 481 62.jpg
# 482 596.jpg
# 483 551.jpg
# 484 248.jpg
# 485 489.jpg
# 486 433.JPG
# 487 49.jpg
# 488 400.jpg
# 489 183.jpg
# 490 594.jpg
# 491 164.jpg
# 492 334.jpg
# 493 546.jpg
# 494 .JPG
# 495 377.jpg
# 496 218.jpg
# 497 3.png
# 498 176.jpg
# 499 518.jpg
# 500 403.jpg
# 501 158.JPG
# 502 354.jpg
# 503 326.jpg
# 504 426.jpg
# 505 155.jpg
# 506 370.jpg
# 507 330.jpg
# 508 349.jpg
# 509 239.jpg
# 510 454.jpg
# 511 521.jpg
# 512 600.jpg
# 513 373.png
# 514 257.jpg
# 515 590.jpg
# 516 212.jpg
# 517 566.jpg
# 518 195.jpg
# 519 534.jpg
# 520 82.jpg
# 521 23.png
# 522 130.png

# %%
import json
json = json.dumps(jsons)
f = open("ocrs_dictionary_improved.json","w")
f.write(json)
f.close()
